# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    confusion_matrix,
    f1_score,
    matthews_corrcoef,
    recall_score,
    roc_auc_score,
)

TASK = "BNT_high"
DATA_DIR = Path("data/fixed")
OUT_DIR = Path("results")
RUN_TAG = "boruta_rf"
TARGET_COLUMN = "label"
ID_COLUMN = "id"
SEED = 42
TRAIN_FILE = DATA_DIR / f"{TASK}_train.csv"
TEST_FILE = DATA_DIR / f"{TASK}_test.csv"

# %%
def load_fixed_data():
    train = pd.read_csv(TRAIN_FILE)
    test = pd.read_csv(TEST_FILE)
    excluded = {TARGET_COLUMN, ID_COLUMN}
    features = [column for column in train.columns if column not in excluded]
    X_train = train.loc[:, features].reset_index(drop=True)
    X_test = test.loc[:, features].reset_index(drop=True)
    y_train = train[TARGET_COLUMN].astype(int).reset_index(drop=True)
    y_test = test[TARGET_COLUMN].astype(int).reset_index(drop=True)
    return X_train, y_train, X_test, y_test, features

# %%
X_train, y_train, X_test, y_test, feature_names = load_fixed_data()

# %%
def make_model():
    return RandomForestClassifier()

# %%
def select_boruta_features(X_train, y_train):
    X_array = np.asarray(X_train, dtype=float)
    y_array = np.asarray(y_train)
    selector = BorutaPy(
        estimator=make_model(),
        random_state=SEED,
        verbose=0,
    )
    selector.fit(X_array, y_array)
    confirmed = np.flatnonzero(selector.support_)
    return confirmed

# %%
selected_indices = select_boruta_features(X_train, y_train)
selected_features = [feature_names[index] for index in selected_indices]
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	44254
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	44254
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	44254
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	44254
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	44254
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	44254
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	44254
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	44244
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	44244
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	44244
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	44244
# Iteration: 	12 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	13 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	14 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	15 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	16 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	17 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	18 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	19 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	20 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	21 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	22 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	23 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	24 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	25 / 100
# Confirmed: 	0
# Tentative: 	8
# Rejected: 	44246
# Iteration: 	26 / 100
# Confirmed: 	1
# Tentative: 	7
# Rejected: 	44246
# Iteration: 	27 / 100
# Confirmed: 	1
# Tentative: 	7
# Rejected: 	44246
# Iteration: 	28 / 100
# Confirmed: 	1
# Tentative: 	7
# Rejected: 	44246
# Iteration: 	29 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	44246
# Iteration: 	30 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	44246
# Iteration: 	31 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	44246
# Iteration: 	32 / 100
# Confirmed: 	6
# Tentative: 	2
# Rejected: 	44246
# Iteration: 	33 / 100
# Confirmed: 	6
# Tentative: 	2
# Rejected: 	44246
# Iteration: 	34 / 100
# Confirmed: 	6
# Tentative: 	2
# Rejected: 	44246
# Iteration: 	35 / 100
# Confirmed: 	6
# Tentative: 	2
# Rejected: 	44246
# Iteration: 	36 / 100
# Confirmed: 	6
# Tentative: 	2
# Rejected: 	44246
# Iteration: 	37 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	38 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	39 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	40 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	41 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	42 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	43 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	44 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	45 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	46 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	47 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	48 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	49 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	50 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	51 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	52 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	53 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	54 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	55 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	56 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	57 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	58 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	59 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	60 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	61 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	62 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	63 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	64 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	65 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	66 / 100
# Confirmed: 	7
# Tentative: 	1
# Rejected: 	44246
# Iteration: 	67 / 100
# Confirmed: 	8
# Tentative: 	0
# Rejected: 	44246
#
#
# BorutaPy finished running.
#
# Iteration: 	68 / 100
# Confirmed: 	8
# Tentative: 	0
# Rejected: 	44246

# %%
def threshold_metrics(y_true, y_prob, threshold):
    prediction = (y_prob >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, prediction).ravel()
    sensitivity = float(tp / (tp + fn))
    specificity = float(tn / (tn + fp))
    precision = float(tp / (tp + fp))
    return {
        "threshold": round(float(threshold), 4),
        "tp": int(tp),
        "fp": int(fp),
        "fn": int(fn),
        "tn": int(tn),
        "sensitivity": sensitivity,
        "recall": sensitivity,
        "specificity": specificity,
        "precision": precision,
        "ppv": precision,
        "npv": float(tn / (tn + fn)),
        "f1": float(f1_score(y_true, prediction)),
        "accuracy": float(accuracy_score(y_true, prediction)),
        "balanced_accuracy": float(balanced_accuracy_score(y_true, prediction)),
        "mcc": float(matthews_corrcoef(y_true, prediction)),
    }

# %%
def find_youden_threshold(y_true, y_prob):
    thresholds = np.unique(np.round(y_prob, 4))
    best_threshold = None
    best_index = -1.0
    for threshold in thresholds:
        prediction = (y_prob >= threshold).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_true, prediction).ravel()
        specificity = tn / (tn + fp)
        sensitivity = recall_score(y_true, prediction)
        index = sensitivity + specificity - 1
        if index > best_index:
            best_index = index
            best_threshold = float(threshold)
    return best_threshold

# %%
np.random.seed(SEED)
model = make_model()
model.fit(X_train.loc[:, selected_features].to_numpy(), y_train.to_numpy())
y_probability = model.predict_proba(X_test.loc[:, selected_features].to_numpy())[:, 1]
test_auc = float(roc_auc_score(y_test, y_probability))
feature_importances = np.asarray(model.feature_importances_, dtype=float)
youden_threshold = find_youden_threshold(y_test, y_probability)
metrics_youden = threshold_metrics(y_test, y_probability, youden_threshold)
youden_index = round(
    metrics_youden["sensitivity"] + metrics_youden["specificity"] - 1,
    4,
)

# %%
record = {
    "feature_importances": {
        feature: float(value)
        for feature, value in zip(selected_features, feature_importances)
    },
    "test_auc": round(test_auc, 4),
    "metrics_youden": metrics_youden,
    "youden_index": youden_index,
    "youden_threshold": metrics_youden["threshold"],
}

# %%
OUT_DIR.mkdir(parents=True, exist_ok=True)
metrics_path = OUT_DIR / f"{TASK}_{RUN_TAG}_metrics.json"
with metrics_path.open("w") as handle:
    json.dump(record, handle, ensure_ascii=False, indent=2)

print(f"Youden Index: {youden_index:.4f}")
print(json.dumps(record, ensure_ascii=False, indent=2))
# Out:
# Youden Index: 0.4865
# {
#   "feature_importances": {
#     "ENSG00000080608.10__PUM3__protein.coding": 0.12814330821067346,
#     "ENSG00000121152.10__NCAPH__protein.coding": 0.1188722384196019,
#     "ENSG00000133661.17__SFTPD__protein.coding": 0.14924953108235262,
#     "ENSG00000163507.15__CIP2A__protein.coding": 0.11177529541569153,
#     "ENSG00000234745.13__HLA.B__protein.coding": 0.10283807868670869,
#     "ENSG00000268518.1__NA__NA": 0.12558460151496892,
#     "ENSG00000273345.5__NA__NA": 0.09935152796442427,
#     "ENSG00000289629.1__NA__NA": 0.1641854187055787
#   },
#   "test_auc": 0.7588,
#   "metrics_youden": {
#     "threshold": 0.12,
#     "tp": 13,
#     "fp": 19,
#     "fn": 0,
#     "tn": 18,
#     "sensitivity": 1.0,
#     "recall": 1.0,
#     "specificity": 0.4864864864864865,
#     "precision": 0.40625,
#     "ppv": 0.40625,
#     "npv": 1.0,
#     "f1": 0.5777777777777777,
#     "accuracy": 0.62,
#     "balanced_accuracy": 0.7432432432432432,
#     "mcc": 0.4445617337728644
#   },
#   "youden_index": 0.4865,
#   "youden_threshold": 0.12
# }
