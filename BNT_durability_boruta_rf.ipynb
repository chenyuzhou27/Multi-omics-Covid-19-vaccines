# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    confusion_matrix,
    f1_score,
    matthews_corrcoef,
    recall_score,
    roc_auc_score,
)

TASK = "BNT_durability"
DATA_DIR = Path("data/fixed")
OUT_DIR = Path("results")
RUN_TAG = "boruta_rf"
TARGET_COLUMN = "label"
ID_COLUMN = "id"
SEED = 42
TRAIN_FILE = DATA_DIR / f"{TASK}_train.csv"
TEST_FILE = DATA_DIR / f"{TASK}_test.csv"

# %%
def load_fixed_data():
    train = pd.read_csv(TRAIN_FILE)
    test = pd.read_csv(TEST_FILE)
    excluded = {TARGET_COLUMN, ID_COLUMN}
    features = [column for column in train.columns if column not in excluded]
    X_train = train.loc[:, features].reset_index(drop=True)
    X_test = test.loc[:, features].reset_index(drop=True)
    y_train = train[TARGET_COLUMN].astype(int).reset_index(drop=True)
    y_test = test[TARGET_COLUMN].astype(int).reset_index(drop=True)
    return X_train, y_train, X_test, y_test, features

# %%
X_train, y_train, X_test, y_test, feature_names = load_fixed_data()

# %%
def make_model():
    return RandomForestClassifier()

# %%
def select_boruta_features(X_train, y_train):
    X_array = np.asarray(X_train, dtype=float)
    y_array = np.asarray(y_train)
    selector = BorutaPy(
        estimator=make_model(),
        random_state=SEED,
        verbose=0,
    )
    selector.fit(X_array, y_array)
    confirmed = np.flatnonzero(selector.support_)
    return confirmed

# %%
selected_indices = select_boruta_features(X_train, y_train)
selected_features = [feature_names[index] for index in selected_indices]
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	44208
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	44208
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	44208
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	44208
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	44208
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	44208
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	44208
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	12 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	13 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	14 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	15 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	16 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	17 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	18 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	44193
# Iteration: 	19 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	20 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	21 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	22 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	23 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	24 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	25 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	26 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	27 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	28 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	44193
# Iteration: 	29 / 100
# Confirmed: 	2
# Tentative: 	13
# Rejected: 	44193
# Iteration: 	30 / 100
# Confirmed: 	2
# Tentative: 	13
# Rejected: 	44193
# Iteration: 	31 / 100
# Confirmed: 	2
# Tentative: 	13
# Rejected: 	44193
# Iteration: 	32 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	44193
# Iteration: 	33 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	44193
# Iteration: 	34 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	44193
# Iteration: 	35 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	44193
# Iteration: 	36 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	44193
# Iteration: 	37 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	38 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	39 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	40 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	41 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	42 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	43 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	44 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	45 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	46 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	47 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	48 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	49 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	50 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	51 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	52 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	53 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	54 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	55 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	56 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	57 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	58 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	59 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	60 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	61 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	62 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	63 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	64 / 100
# Confirmed: 	12
# Tentative: 	3
# Rejected: 	44193
# Iteration: 	65 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	66 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	67 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	68 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	69 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	70 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	71 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	72 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	73 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	74 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	75 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	76 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	77 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	78 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	79 / 100
# Confirmed: 	13
# Tentative: 	2
# Rejected: 	44193
# Iteration: 	80 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	81 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	82 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	83 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	84 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	85 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	86 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	87 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	88 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	89 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	90 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	91 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	92 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	93 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	94 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	95 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	96 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	97 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	98 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
# Iteration: 	99 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	44193

# %%
def threshold_metrics(y_true, y_prob, threshold):
    prediction = (y_prob >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, prediction).ravel()
    sensitivity = float(tp / (tp + fn))
    specificity = float(tn / (tn + fp))
    precision = float(tp / (tp + fp))
    return {
        "threshold": round(float(threshold), 4),
        "tp": int(tp),
        "fp": int(fp),
        "fn": int(fn),
        "tn": int(tn),
        "sensitivity": sensitivity,
        "recall": sensitivity,
        "specificity": specificity,
        "precision": precision,
        "ppv": precision,
        "npv": float(tn / (tn + fn)),
        "f1": float(f1_score(y_true, prediction)),
        "accuracy": float(accuracy_score(y_true, prediction)),
        "balanced_accuracy": float(balanced_accuracy_score(y_true, prediction)),
        "mcc": float(matthews_corrcoef(y_true, prediction)),
    }

# %%
def find_youden_threshold(y_true, y_prob):
    thresholds = np.unique(np.round(y_prob, 4))
    best_threshold = None
    best_index = -1.0
    for threshold in thresholds:
        prediction = (y_prob >= threshold).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_true, prediction).ravel()
        specificity = tn / (tn + fp)
        sensitivity = recall_score(y_true, prediction)
        index = sensitivity + specificity - 1
        if index > best_index:
            best_index = index
            best_threshold = float(threshold)
    return best_threshold

# %%
np.random.seed(SEED)
model = make_model()
model.fit(X_train.loc[:, selected_features].to_numpy(), y_train.to_numpy())
y_probability = model.predict_proba(X_test.loc[:, selected_features].to_numpy())[:, 1]
test_auc = float(roc_auc_score(y_test, y_probability))
feature_importances = np.asarray(model.feature_importances_, dtype=float)
youden_threshold = find_youden_threshold(y_test, y_probability)
metrics_youden = threshold_metrics(y_test, y_probability, youden_threshold)
youden_index = round(
    metrics_youden["sensitivity"] + metrics_youden["specificity"] - 1,
    4,
)

# %%
record = {
    "feature_importances": {
        feature: float(value)
        for feature, value in zip(selected_features, feature_importances)
    },
    "test_auc": round(test_auc, 4),
    "metrics_youden": metrics_youden,
    "youden_index": youden_index,
    "youden_threshold": metrics_youden["threshold"],
}

# %%
OUT_DIR.mkdir(parents=True, exist_ok=True)
metrics_path = OUT_DIR / f"{TASK}_{RUN_TAG}_metrics.json"
with metrics_path.open("w") as handle:
    json.dump(record, handle, ensure_ascii=False, indent=2)

print(f"Youden Index: {youden_index:.4f}")
print(json.dumps(record, ensure_ascii=False, indent=2))
# Out:
# Youden Index: 0.5218
# {
#   "feature_importances": {
#     "ENSG00000000971.16__CFH__protein.coding": 0.09182036606782283,
#     "ENSG00000037280.16__FLT4__protein.coding": 0.07850226904076464,
#     "ENSG00000048342.18__CC2D2A__protein.coding": 0.07788528376945354,
#     "ENSG00000087302.9__RTRAF__protein.coding": 0.05861975941070135,
#     "ENSG00000112183.15__RBM24__protein.coding": 0.07721873499043304,
#     "ENSG00000120093.12__HOXB3__protein.coding": 0.06348034187753018,
#     "ENSG00000150938.10__CRIM1__protein.coding": 0.06071406861595109,
#     "ENSG00000173064.14__HECTD4__protein.coding": 0.05912842280239224,
#     "ENSG00000181350.12__LRRC75A__protein.coding": 0.08392492419975464,
#     "ENSG00000196914.9__ARHGEF12__protein.coding": 0.06226611872676349,
#     "ENSG00000197498.13__RPF2__protein.coding": 0.0784102251178748,
#     "ENSG00000232434.3__AJM1__protein.coding": 0.05318547538735843,
#     "ENSG00000278133.1__NA__NA": 0.07433513198650747,
#     "C15755__14.Ethyl.13.hydroxy.3.5.7.9.13.pentamethyl.2.4.10.trioxooxacyclotetradecan.6.yl.3.4.6.trideoxy.3..dimethylamino.hexopyranoside": 0.08050887800669239
#   },
#   "test_auc": 0.7422,
#   "metrics_youden": {
#     "threshold": 0.21,
#     "tp": 11,
#     "fp": 12,
#     "fn": 2,
#     "tn": 25,
#     "sensitivity": 0.8461538461538461,
#     "recall": 0.8461538461538461,
#     "specificity": 0.6756756756756757,
#     "precision": 0.4782608695652174,
#     "ppv": 0.4782608695652174,
#     "npv": 0.9259259259259259,
#     "f1": 0.6111111111111112,
#     "accuracy": 0.72,
#     "balanced_accuracy": 0.7609147609147608,
#     "mcc": 0.45925657558814553
#   },
#   "youden_index": 0.5218,
#   "youden_threshold": 0.21
# }
