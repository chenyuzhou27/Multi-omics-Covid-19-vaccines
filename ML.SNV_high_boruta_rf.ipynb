# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    confusion_matrix,
    f1_score,
    matthews_corrcoef,
    recall_score,
    roc_auc_score,
)

TASK = "SNV_high"
DATA_DIR = Path("data/fixed")
OUT_DIR = Path("results")
RUN_TAG = "boruta_rf"
TARGET_COLUMN = "label"
ID_COLUMN = "id"
SEED = 42
TRAIN_FILE = DATA_DIR / f"{TASK}_train.csv"
TEST_FILE = DATA_DIR / f"{TASK}_test.csv"

# %%
def load_fixed_data():
    train = pd.read_csv(TRAIN_FILE)
    test = pd.read_csv(TEST_FILE)
    excluded = {TARGET_COLUMN, ID_COLUMN}
    features = [column for column in train.columns if column not in excluded]
    X_train = train.loc[:, features].reset_index(drop=True)
    X_test = test.loc[:, features].reset_index(drop=True)
    y_train = train[TARGET_COLUMN].astype(int).reset_index(drop=True)
    y_test = test[TARGET_COLUMN].astype(int).reset_index(drop=True)
    return X_train, y_train, X_test, y_test, features

# %%
X_train, y_train, X_test, y_test, feature_names = load_fixed_data()

# %%
def make_model():
    return RandomForestClassifier()

# %%
def select_boruta_features(X_train, y_train):
    X_array = np.asarray(X_train, dtype=float)
    y_array = np.asarray(y_train)
    selector = BorutaPy(
        estimator=make_model(),
        random_state=SEED,
        verbose=0,
    )
    selector.fit(X_array, y_array)
    confirmed = np.flatnonzero(selector.support_)
    return confirmed

# %%
selected_indices = select_boruta_features(X_train, y_train)
selected_features = [feature_names[index] for index in selected_indices]
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	44060
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	44060
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	44060
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	44060
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	44060
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	44060
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	44060
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	12 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	13 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	14 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	15 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	16 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	17 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	18 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	19 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	20 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	21 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	22 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	23 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	24 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	25 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	26 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	27 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	28 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	29 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	30 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	31 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	44054
# Iteration: 	32 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	44054
# Iteration: 	33 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	44054
# Iteration: 	34 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	44054
# Iteration: 	35 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	44054
# Iteration: 	36 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	44054
# Iteration: 	37 / 100
# Confirmed: 	6
# Tentative: 	0
# Rejected: 	44054
#
#
# BorutaPy finished running.
#
# Iteration: 	38 / 100
# Confirmed: 	6
# Tentative: 	0
# Rejected: 	44054

# %%
def threshold_metrics(y_true, y_prob, threshold):
    prediction = (y_prob >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, prediction).ravel()
    sensitivity = float(tp / (tp + fn))
    specificity = float(tn / (tn + fp))
    precision = float(tp / (tp + fp))
    return {
        "threshold": round(float(threshold), 4),
        "tp": int(tp),
        "fp": int(fp),
        "fn": int(fn),
        "tn": int(tn),
        "sensitivity": sensitivity,
        "recall": sensitivity,
        "specificity": specificity,
        "precision": precision,
        "ppv": precision,
        "npv": float(tn / (tn + fn)),
        "f1": float(f1_score(y_true, prediction)),
        "accuracy": float(accuracy_score(y_true, prediction)),
        "balanced_accuracy": float(balanced_accuracy_score(y_true, prediction)),
        "mcc": float(matthews_corrcoef(y_true, prediction)),
    }

# %%
def find_youden_threshold(y_true, y_prob):
    thresholds = np.unique(np.round(y_prob, 4))
    best_threshold = None
    best_index = -1.0
    for threshold in thresholds:
        prediction = (y_prob >= threshold).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_true, prediction).ravel()
        specificity = tn / (tn + fp)
        sensitivity = recall_score(y_true, prediction)
        index = sensitivity + specificity - 1
        if index > best_index:
            best_index = index
            best_threshold = float(threshold)
    return best_threshold

# %%
np.random.seed(SEED)
model = make_model()
model.fit(X_train.loc[:, selected_features].to_numpy(), y_train.to_numpy())
y_probability = model.predict_proba(X_test.loc[:, selected_features].to_numpy())[:, 1]
test_auc = float(roc_auc_score(y_test, y_probability))
feature_importances = np.asarray(model.feature_importances_, dtype=float)
youden_threshold = find_youden_threshold(y_test, y_probability)
metrics_youden = threshold_metrics(y_test, y_probability, youden_threshold)
youden_index = round(
    metrics_youden["sensitivity"] + metrics_youden["specificity"] - 1,
    4,
)

# %%
record = {
    "feature_importances": {
        feature: float(value)
        for feature, value in zip(selected_features, feature_importances)
    },
    "test_auc": round(test_auc, 4),
    "metrics_youden": metrics_youden,
    "youden_index": youden_index,
    "youden_threshold": metrics_youden["threshold"],
}

# %%
OUT_DIR.mkdir(parents=True, exist_ok=True)
metrics_path = OUT_DIR / f"{TASK}_{RUN_TAG}_metrics.json"
with metrics_path.open("w") as handle:
    json.dump(record, handle, ensure_ascii=False, indent=2)

print(f"Youden Index: {youden_index:.4f}")
print(json.dumps(record, ensure_ascii=False, indent=2))
# Out:
# Youden Index: 0.5000
# {
#   "feature_importances": {
#     "ENSG00000173545.5__ZNF622__protein.coding": 0.16564175854038699,
#     "ENSG00000242829.1__RPS26P21__pseudo": 0.1559861689867263,
#     "ChE.18.3.": 0.15796502822196348,
#     "X79050__rac.Glycerol.1.myristate": 0.17053086099413992,
#     "HMDB0000847__1.nonanoic.acid": 0.18502411761351403,
#     "HMDB0000930__Trans.cinnamate": 0.16485206564326915
#   },
#   "test_auc": 0.7798,
#   "metrics_youden": {
#     "threshold": 0.14,
#     "tp": 9,
#     "fp": 14,
#     "fn": 0,
#     "tn": 14,
#     "sensitivity": 1.0,
#     "recall": 1.0,
#     "specificity": 0.5,
#     "precision": 0.391304347826087,
#     "ppv": 0.391304347826087,
#     "npv": 1.0,
#     "f1": 0.5625,
#     "accuracy": 0.6216216216216216,
#     "balanced_accuracy": 0.75,
#     "mcc": 0.4423258684646914
#   },
#   "youden_index": 0.5,
#   "youden_threshold": 0.14
# }
